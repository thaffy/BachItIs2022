# %% [markdown]
# ## 1 Naive Bayas

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
from utilities import visualize_classifier              
from sklearn import cross_decomposition
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Load files

# %%
input_file = 'data_multivar_nb.txt'
data = np.loadtxt(input_file, delimiter= ',')

x,y = data[:,:-1], data[:,-1]

# %% [markdown]
# Create Naive Bayes classifier & predict the values for training data

# %%
classifier = GaussianNB()
classifier.fit(x,y)

y_pred = classifier.predict(x)

# %%
accuracy = 100.0 * (y == y_pred).sum() / x.shape[0]
print("Accuracy of Naive Bayes classifier=",round(accuracy,2),"%")

# Visualize the performance of the classifier
visualize_classifier(classifier,x,y)
# Out:
# Accuracy of Naive Bayes classifier= 99.75 %

# %% [markdown]
# ## 2 - Updated classifier, 80% of data used for training, 20% for testing

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=3)
classifier_new = GaussianNB()
classifier_new.fit(x_train, y_train)
y_test_pred = classifier_new.predict(x_test)

# %%
accuracy = 100.0 * (y_test == y_test_pred).sum() / x_test.shape[0]
print("Arruacy of the new classifier =",round(accuracy,2),"%")
visualize_classifier(classifier_new,x_test,y_test)
# Out:
# Arruacy of the new classifier = 100.0 %

# %% [markdown]
# # Sorting functions

# %%
num_folds = 3
accuracy_values = cross_val_score(classifier,
x,y, scoring="accuracy",cv = num_folds)
print("Accuracy: "+ str(round(100*accuracy_values.mean(),2))+"%")
# Out:
# Accuracy: 99.75%

# %%
precision_values = cross_val_score
